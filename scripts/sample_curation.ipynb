# %% [markdown]
# ### Importation des Bibliothèques

# %%
import geopandas as gpd
import sys 
import os
sys.path.append('/home/onyxia/Projet_Teledec/scripts')
from my_function import filter_classes
import pandas as pd

# %%
# definition des paramètres 
my_folder = '/home/onyxia/work/data/project'
out_folder = '/home/onyxia/Projet_Teledec/results/data'
in_vector = os.path.join(my_folder, 'FORMATION_VEGETALE.shp')
emprise_path = os.path.join(my_folder, 'emprise_etude.shp')
out_file = os.path.join(out_folder,'sample/Sample_BD_foret_T31TCJ.shp')

# %%
# Chargement des données de BD_Forêt
bd_foret = gpd.read_file(in_vector)
bd_foret.head()
bd_foret.shape
# Out:
# (24041, 6)

# %%
# Chargement de l'emprise d'étude 
emprise_etude = gpd.read_file(emprise_path)
emprise_etude.head()
# Out:
#           MINX          MINY         MAXX          MAXY        CNTX  \
# 0  501127.9697  6.238861e+06  610073.1663  6.314464e+06  555600.568
#
#            CNTY          AREA        PERIM      HEIGHT        WIDTH  ...  \
# 0  6.276662e+06  8.236616e+09  369096.9934  75603.3001  108945.1966  ...
#
#       MINY_2    MAXX_2     MAXY_2    CNTX_2     CNTY_2        AREA_2  \
# 0  4790220.0  409800.0  4900020.0  354900.0  4845120.0  1.205604e+10
#
#     PERIM_2  HEIGHT_2   WIDTH_2  \
# 0  439200.0  109800.0  109800.0
#
#                                             geometry
# 0  POLYGON ((501127.97 6240794.776, 501127.97 631...
#
# [1 rows x 21 columns]

# %%
bd_foret = bd_foret.to_crs(emprise_etude.crs)
# Découpage de la base de Filtrée en utilisant l'emprise d'étude comme masque 
bd_foret_clipped = bd_foret.clip(emprise_etude)
print(bd_foret_clipped)

# bd_foret_clipped.to_file('/home/onyxia/work/bd_foret_clipped')
# Out:
#                              ID   CODE_TFV  \
# 8719   FORESTIE0000000003108720     FF1-00
# 3109   FORESTIE0000000003103110        LA4
# 8752   FORESTIE0000000003108753     FF1-00
# 16028  FORESTIE0000000003116029  FF1-00-00
# 3102   FORESTIE0000000003103103        LA4
# ...                         ...        ...
# 24013  FORESTIE0000000003124014  FF1G01-01
# 22175  FORESTIE0000000003122176  FF1G01-01
# 22176  FORESTIE0000000003122177  FF1G01-01
# 5178   FORESTIE0000000003105179        LA4
# 1365   FORESTIE0000000003101366        FO1
#
#                                           TFV                 TFV_G11  \
# 8719   Forêt fermée de feuillus purs en îlots   Forêt fermée feuillus
# 3109                                    Lande                   Lande
# 8752   Forêt fermée de feuillus purs en îlots   Forêt fermée feuillus
# 16028      Forêt fermée à mélange de feuillus   Forêt fermée feuillus
# 3102                                    Lande                   Lande
# ...

# %%
bd_foret_classes = bd_foret["TFV"].unique()
bd_foret_classes
#Liste des classes valides 
valide_classes = [
    "Forêt fermée d’un autre feuillu pur",
    "Forêt fermée de châtaignier pur",
    "Forêt fermée de hêtre pur",
    "Forêt fermée de chênes décidus purs",
    "Forêt fermée de robinier pur",
    "Peupleraie",
    "Forêt fermée à mélange de feuillus",
    "Forêt fermée de feuillus purs en îlots",
    "Forêt fermée d’un autre conifère pur autre que pin\xa0",
    "Forêt fermée de mélèze pur",
    "Forêt fermée de sapin ou épicéa",
    "Forêt fermée à mélange d’autres conifères",
    "Forêt fermée d’un autre pin pur",
    "Forêt fermée de pin sylvestre pur",
    "Forêt fermée à mélange de pins purs",
    "Forêt fermée de douglas pur",
    "Forêt fermée de pin laricio ou pin noir pur",
    "Forêt fermée de pin maritime pur",
    "Forêt fermée à mélange de conifères",
    "Forêt fermée de conifères purs en îlots",
    "Forêt fermée à mélange de conifères prépondérants et feuillus",
    "Forêt fermée à mélange de feuillus prépondérants et conifères"
]

filtered_samples = filter_classes(bd_foret, valide_classes)
filtered_samples.head()
filtered_samples_classes = filtered_samples["TFV"].unique()
filtered_samples_classes
# Créeation d'un dictionnaire pour associer à chaque classe de forêt un nom à l'échelle de pixel et aussi à l'échelle de polygone et un code pour chaque classe 
category_mapping = {
    'Forêt fermée d’un autre feuillu pur': {'nom_pixel': 'Autres feuillus', 'Code_pixel': '11', 'Objet_nom': 'Autres feuillus', 'Objet_code': '11'},
    'Forêt fermée de châtaignier pur': {'nom_pixel': 'Autres feuillus', 'Code_pixel': '11', 'Objet_nom': 'Autres feuillus', 'Objet_code': '11'},
    'Forêt fermée de hêtre pur': {'nom_pixel': 'Autres feuillus', 'Code_pixel': '11', 'Objet_nom': 'Autres feuillus', 'Objet_code': '11'},
    'Forêt fermée de chênes décidus purs': {'nom_pixel': 'Chêne', 'Code_pixel': '12', 'Objet_nom': 'Chêne', 'Objet_code': '12'},
    'Forêt fermée de robinier pur': {'nom_pixel': 'Robinier', 'Code_pixel': '13', 'Objet_nom': 'Robinier', 'Objet_code': '13'},
    'Peupleraie': {'nom_pixel': 'Peupleraie', 'Code_pixel': '14', 'Objet_nom': 'Peupleraie', 'Objet_code': '14'},
    'Forêt fermée à mélange de feuillus': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Mélange de feuillus', 'Objet_code': '15'},
    'Forêt fermée de feuillus purs en îlots': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Feuillus en îlots', 'Objet_code': '16'},
    'Forêt fermée d’un autre conifère pur autre que pin': {'nom_pixel': 'Autres conifères autre que pin', 'Code_pixel': '21', 'Objet_nom': 'Autres conifères autre que pin', 'Objet_code': '21'},
    'Forêt fermée de mélèze pur': {'nom_pixel': 'Autres conifères autre que pin', 'Code_pixel': '21', 'Objet_nom': 'Autres conifères autre que pin', 'Objet_code': '21'},
    'Forêt fermée de sapin ou épicéa': {'nom_pixel': 'Autres conifères autre que pin', 'Code_pixel': '21', 'Objet_nom': 'Autres conifères autre que pin', 'Objet_code': '21'},
    'Forêt fermée à mélange d’autres conifères': {'nom_pixel': 'Autres conifères autre que pin', 'Code_pixel': '21', 'Objet_nom': 'Autres conifères autre que pin', 'Objet_code': '21'},
    'Forêt fermée d’un autre pin pur': {'nom_pixel': 'Autres Pin', 'Code_pixel': '22', 'Objet_nom': 'Autres Pin', 'Objet_code': '22'},
    'Forêt fermée de pin sylvestre pur': {'nom_pixel': 'Autres Pin', 'Code_pixel': '22', 'Objet_nom': 'Autres Pin', 'Objet_code': '22'},
    'Forêt fermée à mélange de pins purs': {'nom_pixel': 'Autres Pin', 'Code_pixel': '22', 'Objet_nom': 'Autres Pin', 'Objet_code': '22'},
    'Forêt fermée de douglas pur': {'nom_pixel': 'Douglas', 'Code_pixel': '23', 'Objet_nom': 'Douglas', 'Objet_code': '23'},
    'Forêt fermée de pin laricio ou pin noir pur': {'nom_pixel': 'Pin laricio ou pin noir', 'Code_pixel': '24', 'Objet_nom': 'Pin laricio ou pin noir', 'Objet_code': '24'},
    'Forêt fermée de pin maritime pur': {'nom_pixel': 'Pin maritime', 'Code_pixel': '25', 'Objet_nom': 'Pin maritime', 'Objet_code': '25'},
    'Forêt fermée à mélange de conifères': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Mélange conifères', 'Objet_code': '26'},
    'Forêt fermée de conifères purs en îlots': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Conifères en îlots', 'Objet_code': '27'},
    'Forêt fermée à mélange de conifères prépondérants et feuillus': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Mélange de conifères prépondérants et feuillus', 'Objet_code': '28'},
    'Forêt fermée à mélange de feuillus prépondérants et conifères': {'nom_pixel': '', 'Code_pixel': '', 'Objet_nom': 'Mélange de feuillus prépondérants et conifères', 'Objet_code': '29'},
}

# Application de la fonction map pour parcourir la table attributaire de filtered_samples et ajouter et remplir les colonnes nom et code comme précisé dans le dictionnaire 
df = filtered_samples.join(filtered_samples['TFV'].map(lambda x: category_mapping.get(x, {})).apply(pd.Series))
print(df)
df.head()
# Out:
#                              ID   CODE_TFV  \
# 279    FORESTIE0000000003100280  FF1-00-00
# 589    FORESTIE0000000003100590  FF1-00-00
# 2516   FORESTIE0000000003102517  FF1G01-01
# 4298   FORESTIE0000000003104299  FF1G01-01
# 5184   FORESTIE0000000003105185     FF1-00
# ...                         ...        ...
# 24033  FORESTIE0000000003124034  FF1G01-01
# 24034  FORESTIE0000000003124035  FF1-10-10
# 24036  FORESTIE0000000003124037     FF1-00
# 24038  FORESTIE0000000003124039     FF1-00
# 24040  FORESTIE0000000003124041     FF1-00
#
#                                           TFV                TFV_G11  \
# 279        Forêt fermée à mélange de feuillus  Forêt fermée feuillus
# 589        Forêt fermée à mélange de feuillus  Forêt fermée feuillus
# 2516      Forêt fermée de chênes décidus purs  Forêt fermée feuillus
# 4298      Forêt fermée de chênes décidus purs  Forêt fermée feuillus
# 5184   Forêt fermée de feuillus purs en îlots  Forêt fermée feuillus
# ...

# %%
# Enregistrement de la couche de séléction des échantillons 
df.to_file(out_file)
print("l'enregistrement est réalisé avec succès ")
# Out:
# l'enregistrement est réalisé avec succès
